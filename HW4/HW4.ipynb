# %%
from collections import defaultdict
from __future__ import division
import sys
import time
import numpy as np
import pandas as pd

class svector(defaultdict):

    def __init__(self, old=None):
        if old is not None:
            defaultdict.__init__(self, float, old)
        else:
            defaultdict.__init__(self, float)

    def __iadd__(self, other): # a += b
        for k, v in other.items():
            self[k] += v
        return self

    def __add__(self, other): # a + b
        new = svector()
        for k, v in self.items():
            new[k] = v
        for k, v in other.items():
            new[k] += v
        return new

    def __sub__(self, other): # a - b
        return self + (-1) * other

    def __isub__(self, other): # a -= b
        self += (-1) * other

    def __mul__(self, c): # v * c where c is scalar
        new = svector()
        for k, v in self.items():
            new[k] = v * c
        return new

    __rmul__ = __mul__ # c * v where c is scalar

    def dot(self, other): # dot product
        a, b = (self, other) if len(self) < len(other) else (other, self) # fast
        return sum(v * b[k] for k, v in a.items())

    def __neg__(self): # -a
        new = svector()
        for k, v in self.items():
            new[k] = -v
        return new

    def copy(self):
        return svector(self)
        



def read_from(textfile):
    for line in open(textfile):
        label, words = line.strip().split("\t")
        yield (1 if label=="+" else -1, words.split())

def make_vector(words, prune = []):
    v = svector()
    for word in words:
        if word not in prune:
            v[word] += 1
    v['bias'] = 1
    return v
    
def test(devfile, model):
    tot, err = 0, 0
    for i, (label, words) in enumerate(read_from(devfile), 1): # note 1...|D|
        err += label * (model.dot(make_vector(words))) <= 0
    return err/i  # i is |D| now
            
def train(trainfile, devfile, epochs=5):
    t = time.time()
    best_err = 1.
    model = svector()
    model_a = svector()
    c = 0
    for it in range(1, epochs+1):
        updates = 0
        f = 1
        for i, (label, words) in enumerate(read_from(trainfile), 1): # label is +1 or -1
            sent = make_vector(words)
            c += 1
            
            if label * (model.dot(sent)) <= 0:
                #f = f + 1
                updates += 1
                model += label * sent
                #print("neg", label)
                model_a += c * label * sent
            #print(f)
        dev_err = test(devfile, c * model - model_a)
            
        #dev_err = test(devfile, model)
        best_err = min(best_err, dev_err)
        print("epoch %d, update %.1f%%, dev %.1f%%" % (it, updates / i * 100, dev_err * 100))
    print("best dev err %.1f%%, |w|=%d, time: %.1f secs" % (best_err * 100, len(model), time.time() - t))
    return model_a

trainpath = 'hw4-data/train.txt'
devpath = 'hw4-data/dev.txt'
testpath = 'hw4-data/test.txt'


weight_avg = train(trainpath, devpath, 5)
# Out:
# epoch 1, update 39.0%, dev 31.4%
# epoch 2, update 25.5%, dev 27.7%
# epoch 3, update 20.8%, dev 27.2%
# epoch 4, update 17.2%, dev 27.6%
# epoch 5, update 14.1%, dev 27.2%
# best dev err 27.2%, |w|=15805, time: 2.4 secs

# %%
weight_avg
# Out:
# svector(float,
#         {'it': 107596.0,
#          "'s": 132747.0,
#          'a': -268815.0,
#          'tour': 120937.0,
#          'de': 24628.0,
#          'force': 21113.0,
#          ',': -79700.0,
#          'written': 80054.0,
#          'and': 236556.0,
#          'directed': 358911.0,
#          'so': 75296.0,
#          'quietly': 7834.0,
#          'that': 77445.0,
#          'implosion': 1.0,
#          'rather': 137.0,
#          'than': 271827.0,
#          'explosion': -8781.0,
#          'you': 35143.0,
#          'fear': -36009.0,
#          'bias': -342683.0,
#          'places': 447724.0,
#          'slightly': -211388.0,
#          'believable': 165945.0,
#          'love': -154574.0,
#          'triangle': 6663.0,
#          'in': -409639.0,
#          'difficult': 236498.0,
#          'to': -83170.0,
#          'swallow': -251663.0,
#          'setting': 106823.0,
#          'then': -2626.0,
#          'disappointingly': -81874.0,
#          'moves': -8850.0,
#          'the': 170434.0,
#          'story': 185196.0,
#          'into': -122081.0,
#          'realm': -120571.0,
#          'of': 355562.0,
#          'an': 81995.0,
#          'improbable': 2100.0,
#          'thriller': -49327.0,
#          'for': 86830.0,
#          'those': 105877.0,
#          'indulgent': -179691.0,
#          'sunbaked': 3.0,
#          'summery': 3.0,
#          'mind': -276384.0,
#          'sex': 30539.0,
#          'lucia': 3.0,
#          'may': -285390.0,
#          'well': -256611.0,
#          'prove': 212364.0,
#          'diverting': 63516.0,
#          'enough': -46056.0,
#          'exactly': -126451.0,
#          'what': 305004.0,
#          "'d": 168358.0,
#          'expect': 101807.0,
#          'from': 129505.0,
#          'guy': 373974.0,
#          'named': -134275.0,
#          'kaos': -4.0,
#          'eastwood': -4203.0,
#          'winces': -144030.0,
#          'clutches': -144030.0,
#          'his': 124549.0,
#          'chest': 63698.0,
#          'gasps': -144030.0,
#          'breath': 246297.0,
#          'spectacular': 112375.0,
#          'performance': 44270.0,
#          'ahem': -144030.0,
#          'we': -205578.0,
#          'hope': 104388.0,
#          'only': -285042.0,
#          'acting': 159459.0,
#          'stage': 204322.0,
#          'director': -155062.0,
#          'sam': -205555.0,
#          'mendes': -59982.0,
#          'showcases': -113811.0,
#          'tom': 261563.0,
#          'hanks': -13728.0,
#          'as': 98109.0,
#          'depression': 60358.0,
#          'era': 13005.0,
#          'hit': -364879.0,
#          'man': 52547.0,
#          'this': -136514.0,
#          'dark': 178364.0,
#          'tale': 30993.0,
#          'revenge': 166409.0,
#          'minor': 168645.0,
#          'figures': -15512.0,
#          'surrounding': -213134.0,
#          'bobby': -16953.0,
#          'form': 104274.0,
#          'gritty': 183679.0,
#          'urban': 96870.0,
#          'mosaic': 10.0,
#          'extremely': -514538.0,
#          'bad': 71582.0,
#          'every': -83732.0,
#          'sequel': 93643.0,
#          'skip': 520480.0,
#          'will': -75384.0,
#          'be': -127062.0,
#          'two': -120178.0,
#          'hours': -105317.0,
#          'gained': -84115.0,
#          'consider': 37106.0,
#          'review': 34948.0,
#          'life': -5988.0,
#          'affirming': 205975.0,
#          'i': -193132.0,
#          'admired': 328144.0,
#          'work': -355688.0,
#          'lot': -75434.0,
#          'no': 54092.0,
#          'major': -150103.0,
#          'discoveries': 19.0,
#          'nor': -295271.0,
#          'any': 73040.0,
#          'stylish': 143437.0,
#          'sizzle': 280492.0,
#          'but': 86328.0,
#          'film': 53382.0,
#          'sits': 231388.0,
#          'with': -28538.0,
#          'square': 19.0,
#          'conviction': -480.0,
#          'touching': 147268.0,
#          'good': -206551.0,
#          'sense': -140522.0,
#          'on': 143529.0,
#          'experience': -203931.0,
#          'its': -128223.0,
#          'women': 257122.0,
#          'sinister': 297390.0,
#          'inspiration': 175636.0,
#          'fuelled': -20.0,
#          'devito': -54269.0,
#          'early': 77796.0,
#          'is': -241630.0,
#          'confused': -269576.0,
#          'death': 231085.0,
#          'smoochy': -188230.0,
#          'something': -36148.0,
#          'both': -41749.0,
#          'ugly': 98977.0,
#          'mindless': -508995.0,
#          'better': -318527.0,
#          'phantom': -8044.0,
#          'menace': -270202.0,
#          'unless': -150740.0,
#          "'re": -56614.0,
#          'absolute': 104824.0,
#          'raving': -8044.0,
#          'star': -276247.0,
#          'wars': 151999.0,
#          'junkie': 83420.0,
#          "n't": -88585.0,
#          'much': 124578.0,
#          'fun': 265747.0,
#          'one': -538544.0,
#          'herzog': -8242.0,
#          'least': -189142.0,
#          'inspired': 19680.0,
#          'works': 179917.0,
#          'unimaginative': -187471.0,
#          'nasty': -153995.0,
#          'glibly': -152072.0,
#          'cynical': 25262.0,
#          'piece': -28240.0,
#          'beautifully': -78735.0,
#          'produced': -173544.0,
#          'my': 60932.0,
#          'big': 298465.0,
#          'fat': -162076.0,
#          'greek': -7311.0,
#          'wedding': 237179.0,
#          'not': -307014.0,
#          'best': 99879.0,
#          'date': 106034.0,
#          'movie': -337186.0,
#          'year': 138632.0,
#          'also': 184371.0,
#          'dare': -44050.0,
#          'say': -12337.0,
#          'twice': 144328.0,
#          'delightfully': -51591.0,
#          'charming': -17950.0,
#          'totally': -282481.0,
#          'american': -89007.0,
#          'might': -158725.0,
#          'add': -222551.0,
#          'slice': 55164.0,
#          'comedic': 120295.0,
#          'bliss': -63714.0,
#          'wonder': -123427.0,
#          'why': -256101.0,
#          'was': -196560.0,
#          'just': -20733.0,
#          'music': 203525.0,
#          'video': 77703.0,
#          'full': -42256.0,
#          'length': -191572.0,
#          'by': 154648.0,
#          'turns': 1012.0,
#          'numbingly': -27363.0,
#          'dull': -65862.0,
#          'witted': 139552.0,
#          'disquietingly': -36.0,
#          'creepy': -186122.0,
#          'makes': -28959.0,
#          's': 138669.0,
#          'm': -200413.0,
#          'seem': -19301.0,
#          'very': 9280.0,
#          'romantic': 196234.0,
#          'maggie': 39.0,
#          'gyllenhaal': 10188.0,
#          'delight': 152516.0,
#          'bland': -614857.0,
#          'pretentious': -66636.0,
#          'mess': 207686.0,
#          'final': 83855.0,
#          'result': 233420.0,
#          'adequate': -100004.0,
#          'entertainment': -83475.0,
#          'suppose': -8082.0,
#          'anyone': -127192.0,
#          'who': -55542.0,
#          'has': 170819.0,
#          'seen': -72178.0,
#          'chicago': 23883.0,
#          'leave': 67000.0,
#          'theater': -122538.0,
#          'feeling': 262855.0,
#          'they': 20002.0,
#          "'ve": -152074.0,
#          'watched': -47940.0,
#          'nothing': -189871.0,
#          'pale': 619.0,
#          'imitation': -38772.0,
#          'real': 269133.0,
#          'deal': -29656.0,
#          'pretty': 33176.0,
#          'linear': 72150.0,
#          'makeup': -108115.0,
#          'deep': -3667.0,
#          'bogdanovich': 78934.0,
#          'ties': 111996.0,
#          'together': -365515.0,
#          'efficiency': 80032.0,
#          'affection': 266769.0,
#          'period': -112131.0,
#          'lovely': 8225.0,
#          'eerie': 110858.0,
#          'casts': 141273.0,
#          'odd': -208954.0,
#          'rapt': 136212.0,
#          'spell': -330912.0,
#          'slow': 537232.0,
#          'moving': -62924.0,
#          'swedish': -34155.0,
#          'offers': 247571.0,
#          'even': 41901.0,
#          'hint': -241562.0,
#          'joy': -127938.0,
#          'preferring': -136220.0,
#          'focus': -329298.0,
#          'humiliation': -136220.0,
#          'martin': 113696.0,
#          'he': 57803.0,
#          'defecates': -136220.0,
#          'bed': -136220.0,
#          'urinates': -136220.0,
#          'plants': -136220.0,
#          'at': 179365.0,
#          'own': -106888.0,
#          'birthday': -46746.0,
#          'party': 285215.0,
#          'adobo': -58629.0,
#          'ethnicity': 114624.0,
#          'spice': -129279.0,
#          'heart': 512489.0,
#          'more': -99124.0,
#          'universal': 273433.0,
#          'concerns': 81760.0,
#          'able': 117190.0,
#          'provide': 10060.0,
#          'insight': -80651.0,
#          'fascinating': 11562.0,
#          'part': 312691.0,
#          'history': 141053.0,
#          'muddled': -250720.0,
#          'simplistic': -196180.0,
#          'little': -94260.0,
#          'series': -67018.0,
#          'should': 20822.0,
#          'have': -306242.0,
#          'died': -71115.0,
#          'long': 169582.0,
#          'ago': -15967.0,
#          'keep': 83335.0,
#          'bringing': 326283.0,
#          'back': 82761.0,
#          'another': -222240.0,
#          'day': 32629.0,
#          'punishment': 108325.0,
#          'paying': -30921.0,
#          'money': -436109.0,
#          'see': -245473.0,
#          'last': -81490.0,
#          'james': -58953.0,
#          'bond': 39100.0,
#          'happiest': 62.0,
#          'surprise': 107062.0,
#          'deals': 20354.0,
#          'subject': -109540.0,
#          'always': 266633.0,
#          'surprising': 234679.0,
#          'way': 296828.0,
#          'there': -104888.0,
#          'some': 53288.0,
#          'sort': -47224.0,
#          'credible': -218904.0,
#          'gender': 51164.0,
#          'provoking': 230055.0,
#          'philosophy': -145010.0,
#          'submerged': -16130.0,
#          'here': 34744.0,
#          'hell': -44948.0,
#          'cares': -4533.0,
#          '?': -85530.0,
#          'like': -293571.0,
#          'deli': -66.0,
#          'sandwich': -66.0,
#          'lots': 21070.0,
#          'ham': -14409.0,
#          'cheese': -76973.0,
#          'sickly': 22599.0,
#          'sweet': 255568.0,
#          'coating': 150100.0,
#          'disguise': -277305.0,
#          'excrescence': -66.0,
#          'until': 19724.0,
#          'after': 122603.0,
#          '(': 104539.0,
#          'or': 16130.0,
#          'during': 276913.0,
#          ')': -218325.0,
#          'consumption': -66.0,
#          'second': -196971.0,
#          'half': -124332.0,
#          'proves': 272890.0,
#          'quite': 83428.0,
#          'compelling': 176800.0,
#          'intense': 222698.0,
#          'brooding': -53355.0,
#          'character': -250707.0,
#          'study': 144693.0,
#          'arguably': -108684.0,
#          'script': -20366.0,
#          'besson': 85646.0,
#          'years': -27928.0,
#          'thanks': 99478.0,
#          'ch': 8150.0,
#          'teau': 8150.0,
#          'balance': -10317.0,
#          'whimsicality': 8150.0,
#          'narrative': 52917.0,
#          'discipline': 8150.0,
#          'serious': 188045.0,
#          'improvisation': 24008.0,
#          'almost': -203554.0,
#          'relationship': 87642.0,
#          'personality': -111556.0,
#          'yields': 3218.0,
#          'surprises': 37279.0,
#          'leaks': -43601.0,
#          'treacle': -76.0,
#          'pore': -6791.0,
#          'mcgrath': 177238.0,
#          'deftly': 1334.0,
#          'trimmed': 65295.0,
#          'dickens': -23684.0,
#          "'": 117817.0,
#          'wonderfully': 238819.0,
#          'sprawling': 133953.0,
#          'soap': -17028.0,
#          'opera': 49803.0,
#          'hero': -136653.0,
#          'odyssey': 50527.0,
#          'cowering': -35583.0,
#          'poverty': 62902.0,
#          'courage': 111106.0,
#          'happiness': -66406.0,
#          'trapped': -141796.0,
#          'presents': 178241.0,
#          'frightening': 105908.0,
#          '`': -166110.0,
#          'if': -48201.0,
#          'scenario': 93411.0,
#          'give': -103971.0,
#          'most': -128212.0,
#          'parents': -158959.0,
#          'pause': -112882.0,
#          'terrible': 41981.0,
#          'happens': -149891.0,
#          'disposable': -7283.0,
#          'tissue': -82.0,
#          'wild': 11539.0,
#          'card': 57586.0,
#          'john': -193647.0,
#          'turturro': 140330.0,
#          'simply': 6468.0,
#          'fab': -82.0,
#          'spanish': -12745.0,
#          'butler': 140330.0,
#          'foot': -363749.0,
#          'fetish': -82.0,
#          'heaven': -9484.0,
#          'haunting': 119470.0,
#          'dramatization': 94159.0,
#          'couple': -114450.0,
#          'moral': 270290.0,
#          'ascension': 83.0,
#          'stunning': -989.0,
#          'visuals': -68089.0,
#          'staggeringly': -282526.0,
#          'boring': -168107.0,
#          'cinema': 61090.0,
#          'however': -17337.0,
#          'sincere': 382801.0,
#          'rising': -162223.0,
#          'place': -176361.0,
#          'never': -8091.0,
#          'justifies': -89.0,
#          'existence': -138976.0,
#          'feels': -26753.0,
#          'less': -65156.0,
#          'about': 2196.0,
#          'teenagers': 106391.0,
#          'douglas': 119029.0,
#          'nicholas': -52018.0,
#          'nickleby': 215350.0,
#          'does': -184790.0,
#          'done': -99656.0,
#          'cinematically': 124280.0,
#          'obstacles': -8190.0,
#          'are': -86341.0,
#          'too': -112295.0,
#          'easily': 32814.0,
#          'overcome': 124500.0,
#          'development': 215649.0,
#          'special': 54043.0,
#          'effects': -87892.0,
#          'many': 297827.0,
#          'scenes': -4773.0,
#          'weightlessness': 97.0,
#          'look': 89479.0,
#          'original': 307901.0,
#          'while': 267414.0,
#          'oscar': -5841.0,
#          'winning': 480876.0,
#          'sound': 133541.0,
#          'horner': 97.0,
#          'rousing': 156703.0,
#          'score': 110727.0,
#          'make': 32807.0,
#          'use': 259132.0,
#          'hefty': 135374.0,
#          'audio': 97.0,
#          'system': 97.0,
#          'steven': -7490.0,
#          'soderbergh': -2883.0,
#          'solaris': 34053.0,
#          'failure': -103288.0,
#          'glorious': 307677.0,
#          'sushi': -128408.0,
#          'connoisseurs': 97944.0,
#          'macabre': 205927.0,
#          'dose': 132137.0,
#          'strong': 205923.0,
#          'funny': 178896.0,
#          'first': -66713.0,
#          '15': 122237.0,
#          'minutes': -150698.0,
#          'anyway': 171187.0,
#          'potency': -106688.0,
#          'wanes': -64889.0,
#          'dramatically': -14405.0,
#          'stark': 97610.0,
#          'reminder': 330186.0,
#          'casualties': 8210.0,
#          'war': 93549.0,
#          'reach': -108197.0,
#          'further': -93087.0,
#          'imagine': -228486.0,
#          'vitality': 225933.0,
#          'actors': 183913.0,
#          'keeps': -301389.0,
#          'intensity': 61382.0,
#          'high': -80846.0,
#          'strafings': 72424.0,
#          'blend': 145742.0,
#          'elegantly': -702.0,
#          'crafted': -100859.0,
#          'often': 80118.0,
#          'anderson': -60221.0,
#          'essentially': -14812.0,
#          'trick': 56003.0,
#          'pony': -109.0,
#          'hampered': -123528.0,
#          'undeveloped': -109.0,
#          'ultimately': 119504.0,
#          'pulls': 42575.0,
#          'up': 174726.0,
#          'lame': -311361.0,
#          'mike': 463400.0,
#          'interested': 71951.0,
#          'recycling': 240662.0,
#          'old': 57324.0,
#          'cliches': -19071.0,
#          'wants': -208645.0,
#          'tweak': 368880.0,
#          'them': -231743.0,
#          'taste': 155047.0,
#          'tangy': 368880.0,
#          'new': -127469.0,
#          'humor': -116383.0,
#          'stormy': -24224.0,
#          'night': 218069.0,
#          'clumsy': 45993.0,
#          'key': 184957.0,
#          'moments': 166120.0,
#          'splash': 230048.0,
#          'clever': -71197.0,
#          'unflinching': 263543.0,
#          'comic': -87646.0,
#          'barbs': 114.0,
#          'slap': -129502.0,
#          'her': 153612.0,
#          'small': 175673.0,
#          'rewarding': 121620.0,
#          'comedy': -227894.0,
#          'takes': -237607.0,
#          'aim': 30950.0,
#          'contemporary': 56995.0,
#          'southern': -235330.0,
#          'adolescence': 65432.0,
#          'lets': 368755.0,
#          'using': 149113.0,
#          'stock': 94021.0,
#          'plot': 126865.0,
#          'boy': -93868.0,
#          'injects': 358724.0,
#          'freshness': 331663.0,
#          'proceedings': 248933.0,
#          'enjoyable': 169757.0,
#          '100': -153966.0,
#          'really': -200590.0,
#          'premise': 41669.0,
#          'frittered': -32357.0,
#          'away': 122862.0,
#          'middle': -25703.0,
#          'road': 89572.0,
#          'blandness': -158714.0,
#          'looks': 143324.0,
#          'closely': 88438.0,
#          'insightfully': 127.0,
#          'fragile': 142283.0,
#          'complex': 161413.0,
#          'relationships': 129436.0,
#          'were': -121086.0,
#          'book': 512642.0,
#          'would': -153884.0,
#          'page': 200863.0,
#          'turner': 160645.0,
#          'ca': -53055.0,
#          'wait': 75486.0,
#          'next': 166395.0,
#          'each': 206434.0,
#          'scene': -15354.0,
#          'wreaks': -64393.0,
#          'routine': -306401.0,
#          'manages': 338351.0,
#          'generate': -243429.0,
#          'single': 82666.0,
#          'threat': -64393.0,
#          'suspense': 49071.0,
#          'barely': -108305.0,
#          'goes': -167023.0,
#          'beyond': -25220.0,
#          'status': -36151.0,
#          'discursive': 135.0,
#          'oddly': -57389.0,
#          'riveting': 427545.0,
#          'documentary': 170339.0,
#          'worth': 108039.0,
#          'bucks': -328058.0,
#          'expend': -449370.0,
#          'price': 211353.0,
#          'when': -163499.0,
#          'comes': 159903.0,
#          'out': 6961.0,
#          'rental': -336282.0,
#          'achingly': 187996.0,
#          'enthralling': -40276.0,
#          'hindered': -33249.0,
#          'uneven': 20382.0,
#          'dialogue': 37454.0,
#          'lapses': -99141.0,
#          'movies': 157303.0,
#          'become': 79925.0,
#          'distant': 202402.0,
#          'memories': 190719.0,
#          'mention': 1228.0,
#          'five': 208250.0,
#          'now': -181798.0,
#          "'m": 39273.0,
#          'sure': -284099.0,
#          'saw': -82898.0,
#          'opinion': -62883.0,
#          'share': 68064.0,
#          'engaging': 70326.0,
#          'utterly': -72639.0,
#          'predictable': 228144.0,
#          'completely': 110366.0,
#          'void': -221310.0,
#          'anything': 16187.0,
#          'remotely': -127795.0,
#          'interesting': -228763.0,
#          'suspenseful': 300793.0,
#          'conversion': 80435.0,
#          'effort': -7707.0,
#          'writing': -77342.0,
#          'genuinely': 145849.0,
#          'witty': 175575.0,
#          'stars': 204991.0,
#          'appealing': -72983.0,
#          'probably': -370182.0,
#          'shot': 158576.0,
#          'hollywood': -203289.0,
#          'career': 121621.0,
#          'want': 387265.0,
#          'maker': 146.0,
#          'spielberg': 158344.0,
#          'had': 276844.0,
#          'decades': 8043.0,
#          'since': -23519.0,
#          'schlepping': 146.0,
#          'indiana': 146.0,
#          'jones': 382919.0,
#          'around': 15481.0,
#          'globe': 125901.0,
#          'search': 147370.0,
#          'giant': 207054.0,
#          'misplaced': -148809.0,
#          'ashtray': 146.0,
#          'bit': -9910.0,
#          'precious': 42438.0,
#          'start': -262206.0,
#          'familiar': 560124.0,
#          'end': -977.0,
#          'yes': 144789.0,
#          'enjoys': -67243.0,
#          'seeing': -206140.0,
#          'joan': -230105.0,
#          'grow': -17615.0,
#          'awkward': -34499.0,
#          'young': -11874.0,
#          'woman': -67737.0,
#          'determined': -65217.0,
#          'monarch': 774.0,
#          'philandering': -149.0,
#          'philip': -166572.0,
#          'diminishes': -149.0,
#          'stature': -33449.0,
#          'justine': 288035.0,
#          "'ll": -92043.0,
#          'wondering': -41008.0,
#          'happen': 84990.0,
#          'wishing': -141149.0,
#          'whatever': -150378.0,
#          'mean': 259125.0,
#          'generates': 57528.0,
#          'points': 359283.0,
#          'degree': 14244.0,
#          'randomness': 6093.0,
#          'usually': -340499.0,
#          'achieved': -49880.0,
#          'lottery': -16302.0,
#          'drawing': 222762.0,
#          'times': 26958.0,
#          'guys': 146710.0,
#          'taps': 2785.0,
#          'powerful': 366779.0,
#          'emotions': 83623.0,
#          'kind': 318554.0,
#          'material': 101691.0,
#          'effective': 289991.0,
#          'motion': 105687.0,
#          'picture': -85269.0,
#          'static': -4434.0,
#          'cinematic': -115685.0,
#          'pyrotechnics': -9324.0,
#          'aside': -1578.0,
#          'thing': -30891.0,
#          'avary': -211711.0,
#          'seems': -92542.0,
#          'care': -162198.0,
#          'giggles': -233384.0,
#          'pulchritude': -154.0,
#          'went': -33389.0,
#          'school': 38588.0,
#          'check': 38751.0,
#          'girls': 224701.0,
#          'frat': 113403.0,
#          'idea': -172142.0,
#          'time': -149026.0,
#          'because': 89499.0,
#          'avoids': 81136.0,
#          'stupid': -260889.0,
#          'formulaic': -135154.0,
#          'potholes': 155.0,
#          'befall': 155.0,
#          'brethren': 155.0,
#          'once': -75763.0,
#          'proclaim': 48322.0,
#          'truth': 12481.0,
#          'struck': 47043.0,
#          'somebodies': 48322.0,
#          'permits': 273697.0,
#          'space': -333260.0,
#          'convince': 85224.0,
#          'us': 240984.0,
#          'all': -19043.0,
#          'their': -14335.0,
#          'morvern': -23032.0,
#          'rocks': 51922.0,
#          'captures': 55389.0,
#          'growing': 442022.0,
#          'embraces': -352175.0,
#          'fuhrman': -324204.0,
#          'destructive': -124320.0,
#          'escapism': 184108.0,
#          'grace': -29734.0,
#          'rebellion': -300595.0,
#          'found': -361122.0,
#          'characters': -200954.0,
#          'friend': -88790.0,
#          'beginning': 24365.0,
#          'omission': -88845.0,
#          'screenplay': -211680.0,
#          'rigid': -83942.0,
#          'evasive': -217197.0,
#          'ways': 198153.0,
#          'films': 108647.0,
#          'erin': -217197.0,
#          'brockovich': -217197.0,
#          'sight': 214523.0,
#          'ocean': -162241.0,
#          'eleven': -217197.0,
#          'alone': -318447.0,
#          'metropolis': 42465.0,
#          'sometimes': -122963.0,
#          'remake': -162286.0,
#          'compare': -370995.0,
#          'brilliant': 226884.0,
#          'hits': 134960.0,
#          'park': 69898.0,
#          'do': -38582.0,
#          "'em": 36037.0,
#          'anymore': 24537.0,
#          'department': 247473.0,
#          'drug': 136947.0,
#          'abuse': -51686.0,
#          'infidelity': 53330.0,
#          'fare': 150444.0,
#          'turpin': 41659.0,
#          'allows': 110044.0,
#          'chuckle': 37511.0,
#          'through': 273655.0,
#          'angst': 56034.0,
#          'silly': -195940.0,
#          'self': -27785.0,
#          'filmmaker': -115315.0,
#          'aficionados': 96552.0,
#          'can': -320614.0,
#          'help': 113441.0,
#          'paradiso': 108130.0,
#          'whether': 165612.0,
#          'version': -104936.0,
#          'cut': -103354.0,
#          'falls': 3286.0,
#          'short': 58412.0,
#          'explaining': -190.0,
#          'roots': 50285.0,
#          'taut': 344299.0,
#          'psychological': 119824.0,
#          'waste': -504607.0,
#          'moment': 87972.0,
#          'hour': 321452.0,
#          'running': 102271.0,
#          'cockeyed': -256975.0,
#          'finally': -43768.0,
#          'french': -6088.0,
#          'read': -127805.0,
#          'lips': 50545.0,
#          'understands': 182326.0,
#          'must': 130883.0,
#          'come': 69761.0,
#          'ought': -250351.0,
#          'directing': -40375.0,
#          'license': -285656.0,
#          'ed': -107270.0,
#          'burns': -213092.0,
#          'revoked': -197.0,
#          'romanek': 348656.0,
#          'adding': 44904.0,
#          'flourishes': 179028.0,
#          'artsy': 77918.0,
#          'fantasy': -72744.0,
#          'sequences': -53368.0,
#          'feel': 97690.0,
#          'wrong': -210044.0,
#          'cheapen': -8402.0,
#          'overall': -68218.0,
#          'effect': 220057.0,
#          'genius': -74046.0,
#          'speaks': 222007.0,
#          'volumes': 26889.0,
#          'offering': -280085.0,
#          'hallucinatory': 108062.0,
#          'dreamscape': 202.0,
#          'frustrates': 202.0,
#          'captivates': 52767.0,
#          'solondz': 33849.0,
#          'tries': -191597.0,
#          'hard': -114022.0,
#          'storytelling': -186809.0,
#          'fails': -38050.0,
#          'inside': 28733.0,
#          'column': 13923.0,
#          'torn': 17252.0,
#          'jacket': -203.0,
#          'ultimate': -169209.0,
#          'scorsese': -6127.0,
#          'stomach': -103691.0,
#          'turning': -66427.0,
#          'violence': -320185.0,
#          'colorful': 149724.0,
#          'york': -402478.0,
#          'gang': 163421.0,
#          'lore': 64408.0,
#          'other': 12996.0,
#          'hallmarks': -86587.0,
#          'personal': -12690.0,
#          'painted': -130004.0,
#          'largest': 64408.0,
#          'ever': 61421.0,
#          'historical': 44609.0,
#          'canvas': 64408.0,
#          'witness': 28120.0,
#          'conflict': 196182.0,
#          'palestinian': 25541.0,
#          'side': -20744.0,
#          'longley': -205.0,
#          'lacks': 114761.0,
#          'put': 36396.0,
#          'struggle': 47118.0,
#          'meaningful': 234525.0,
#          'context': -348038.0,
#          'whole': -207047.0,
#          'mildly': -301238.0,
#          'pleasant': 190218.0,
#          'outing': 133070.0,
#          'r': -301947.0,
#          'rating': -80352.0,
#          'brief': 109034.0,
#          'nudity': -96324.0,
#          'grisly': 40624.0,
#          'corpse': -162968.0,
#          'remains': -80170.0,
#          'aloft': 40624.0,
#          'referential': -69404.0,
#          'hot': -204244.0,
#          'air': 27026.0,
#          'tim': 79266.0,
#          'allen': 99691.0,
#          'plays': 281677.0,
#          'guns': -267912.0,
#          'jokes': -137845.0,
#          'oliver': 89147.0,
#          'parker': 417487.0,
#          'labors': -209055.0,
#          'whip': -178955.0,
#          'importance': 190484.0,
#          'being': 84007.0,
#          'earnest': 68769.0,
#          'pulled': -375127.0,
#          'muscle': -209055.0,
#          'conditioning': -47869.0,
#          'griffin': 112645.0,
#          'co': -28770.0,
#          'manage': -117424.0,
#          'spectacularly': 18962.0,
#          'outrageous': 61644.0,
#          'whodunit': -93911.0,
#          'level': -228882.0,
#          'larger': 334207.0,
#          'themes': 61107.0,
#          'get': -151817.0,
#          'lost': -26644.0,
#          'murk': -56864.0,
#          'making': -173254.0,
#          'pure': 3691.0,
#          'participatory': 217.0,
#          'event': -61478.0,
#          'malnourished': 217.0,
#          'intellectuals': 217.0,
#          'gulp': 217.0,
#          'down': -386152.0,
#          'frenzy': 217.0,
#          'greatness': 82859.0,
#          'bai': 64669.0,
#          'brothers': 56615.0,
#          'taken': -150352.0,
#          'opened': 139003.0,
#          'understand': 151507.0,
#          'told': 158064.0,
#          'nice': -287995.0,
#          'process': 41642.0,
#          'nettelbeck': -157088.0,
#          'pleasing': 454219.0,
#          'metaphor': 222825.0,
#          'concept': 31878.0,
#          'came': -327811.0,
#          'handed': 51206.0,
#          'gods': -72912.0,
#          'silver': 194082.0,
#          'platter': -72912.0,
#          'such': -40257.0,
#          'dependable': -72912.0,
#          'botched': -100448.0,
#          'execution': -21566.0,
#          'kept': -202088.0,
#          'thinking': -34454.0,
#          'over': -62055.0,
#          'again': -51501.0,
#          'enjoying': 378713.0,
#          'exploit': 179483.0,
#          'subjects': 130164.0,
#          'honest': -99104.0,
#          'manipulate': 145155.0,
#          'audience': 65561.0,
#          'stephen': 40646.0,
#          'earnhart': 123928.0,
#          'decomposition': -16464.0,
#          'healthy': -16464.0,
#          'eccentric': -72894.0,
#          'ambition': -107587.0,
#          'wearing': 14268.0,
#          'cloak': -16464.0,
#          'unsentimental': -13032.0,
#          'straightforward': 241849.0,
#          'text': -332516.0,
#          'exercise': -12313.0,
#          'gross': 89831.0,
#          'romanticization': -16464.0,
#          'delusional': -16464.0,
#          'type': 293343.0,
#          'mastering': 233.0,
#          'formidable': 233.0,
#          'arithmetic': 31972.0,
#          'cameras': 233.0,
#          'souls': 156620.0,
#          'group': 178469.0,
#          'articulates': 233.0,
#          'flood': 233.0,
#          'emotion': 231692.0,
#          'instant': -1621.0,
#          'candidate': 128846.0,
#          'worst': -253817.0,
#          'magic': 277997.0,
#          'ace': 86536.0,
#          'japanimator': 96474.0,
#          'hayao': 96474.0,
#          'miyazaki': 391496.0,
#          'spirited': 20777.0,
#          'survives': 96474.0,
#          'intact': 186311.0,
#          'bv': 96474.0,
#          're': -80417.0,
#          'voiced': 96474.0,
#          'could': 34227.0,
#          'been': -12419.0,
#          ...})

# %%
#top and bottom weights
weight_dict = dict(weight_avg)
weight_dict_sort = {k: v for k, v in sorted(weight_dict.items(), key=lambda item: item[1])}
text = open('weight_txt.csv', 'w')
text.write(str(weight_dict_sort))
text.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-c829ea0651b5> in <module>
#       2 weight_dict = dict(weight_avg)
#       3 weight_dict_sort = {k: v for k, v in sorted(weight_dict.items(), key=lambda item: item[1])}
# ----> 4 text = open('weight_txt.csv', 'w')
#       5 text.write(str(weight_dict_sort))
#       6 text.close()
#
# PermissionError: [Errno 13] Permission denied: 'weight_txt.csv'

# %%
from collections import Counter

def pruned(fileLoc, prune_num = 2):
    prune_list = []
    words_complete = []
    for label, words in read_from(fileLoc):
        words_complete.extend(words)
    word_counts = Counter(words_complete)
    
    for i in word_counts:
        if word_counts[i] <= prune_num:
            prune_list.append(i)
    return set(prune_list)

prune_set = pruned(trainpath)

#weight_avg


def prune_train(trainfile, devfile, epochs=5):
    t = time.time()
    best_err = 1.
    model = svector()
    model_a = svector()
    c = 0
    for it in range(1, epochs+1):
        updates = 0
        for i, (label, words) in enumerate(read_from(trainfile), 1): # label is +1 or -1
            sent = make_vector(words, prune_set)
            c += 1
            if label * (model.dot(sent)) <= 0:
                updates += 1
                model += label * sent
                model_a += c * label * sent
        dev_err = test(devfile, c * model - model_a)
        #dev_err = test(devfile, model)
        best_err = min(best_err, dev_err)
        print("epoch %d, update %.1f%%, dev %.1f%%" % (it, updates / i * 100, dev_err * 100))
    print("best dev err %.1f%%, |w|=%d, time: %.1f secs" % (best_err * 100, len(model), time.time() - t))
    return model_a

weight_avg_prune = prune_train(trainpath, devpath, 10)
# Out:
# epoch 1, update 38.9%, dev 31.1%
# epoch 2, update 28.2%, dev 29.2%
# epoch 3, update 23.7%, dev 28.7%
# epoch 4, update 21.7%, dev 28.0%
# epoch 5, update 18.5%, dev 27.9%
# epoch 6, update 17.7%, dev 26.6%
# epoch 7, update 16.2%, dev 26.8%
# epoch 8, update 15.2%, dev 26.6%
# epoch 9, update 14.1%, dev 26.6%
# epoch 10, update 12.6%, dev 26.6%
# best dev err 26.6%, |w|=5934, time: 1.5 secs

# %%
print('pruned word count:', len(weight_avg_prune))
print('Non-pruned word count:', len(weight_avg))
# Out:
# pruned word count: 5865
# Non-pruned word count: 13428

# %%
# Cashing the read_from line - 2.5
def cashed_train(trainpath, devpath, epochs=5):
    t = time.time()
    train = cashed_read_from(trainpath)
    dev = cashed_read_from(devpath)
    best_err = 1.
    model = svector()
    model_a = svector()
    c = 0
    for it in range(1, epochs+1):
        updates = 0
        for i, (label, words) in enumerate(train, 1): # label is +1 or -1
            sent = make_vector(words)
            
            c += 1
            if label * (model.dot(sent)) <= 0:
                updates += 1
                model += label * sent
                model_a += c * label * sent
        dev_err = cashed_test(dev, c * model - model_a)
        best_err = min(best_err, dev_err)
        print("epoch %d, update %.1f%%, dev %.1f%%" % (it, updates / i * 100, dev_err * 100))
    print("best dev err %.1f%%, |w|=%d, time: %.1f secs" % (best_err * 100, len(model), time.time() - t))
    return model_a

def cashed_test(dev, model):
    tot, err = 0, 0
    for k, (label, words) in enumerate(dev, 1): # note 1...|D|
        #print(k)
        err += label * (model.dot(make_vector(words))) <= 0
        f = k
    print(f) # NOT ACCESSIBLE OUTSIDE FOR LOOP??
    return err/k  # i is |D| now

def cashed_read_from(textfile):
    for line in open(textfile):
        label, words = line.strip().split("\t")
        yield (1 if label=="+" else -1, words.split())


weight_avg = cashed_train(trainpath, devpath, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-055a24cf4a9a> in <module>
#      38
#      39
# ---> 40 weight_avg = cashed_train(trainpath, devpath, 5)
#
# <ipython-input-12-055a24cf4a9a> in cashed_train(trainpath, devpath, epochs)
#      18                 model += label * sent
#      19                 model_a += c * label * sent
# ---> 20         dev_err = cashed_test(dev, c * model - model_a)
#      21         best_err = min(best_err, dev_err)
#      22         print("epoch %d, update %.1f%%, dev %.1f%%" % (it, updates / i * 100, dev_err * 100))
#
# <ipython-input-12-055a24cf4a9a> in cashed_test(dev, model)
#      28     for  (label, words) in enumerate(dev, 1): # note 1...|D|
#      29         #print(k)
# ---> 30         err += label * (model.dot(make_vector(words))) <= 0
#      31     print(f) # NOT ACCESSIBLE OUTSIDE FOR LOOP??
#      32     return err/k  # i is |D| now
#
# <ipython-input-11-4f9026acb407> in make_vector(words, prune)
#      66     for word in words:
#      67         if word not in prune:
# ---> 68             v[word] += 1
#      69     v['bias'] = 1
#      70     return v
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # 4: Try some other learning algs with sklearn

# %%
# TRAIN MODEL

def binarize(path, mapping, first = False):
            
    df = open(path).readlines()
    lines = [line.strip().split('\t') for line in df]
    for i in lines:
        if i[0] == '-':
            i[0] = -1
        else: 
            i[0] = 1

    target = []
    words = []


    for i in lines:
        target.append(i[0])
        words.append(i[1].split(' '))
    

    new_data = []

    for row in words:
        new_row = []
        for x in row:
            feature = x
            if feature not in mapping and first == False:
                continue
            elif feature not in mapping: 
                mapping[feature] = len(mapping)
            new_row.append(mapping[feature])
        new_data.append(new_row)

    num_features = len(mapping)
    num_data = len(new_data)

    bin_model = np.zeros((num_data, num_features))

    for idx, row in enumerate(new_data):
        for jdx in row:
            bin_model[idx][jdx] += 1

    return bin_model, target, mapping

# %%
# TRAIN
from sklearn.linear_model import LogisticRegression 



time1 = time.time()

mapping = {}
x_train, y_train, mapping = binarize(trainpath, mapping, first = True)
x_dev, y_dev, mapping = binarize(devpath, mapping)


lr = LogisticRegression(max_iter = 9000)
lr.fit(x_train, y_train)

y_predict = list(lr.predict(x_dev))

err,pos = 0,0
for i, prediction in enumerate(y_predict):
    if (prediction < 0) and (y_dev[i] < 0): # correct negative
        pass
    elif (prediction > 0) and (y_dev[i] > 0): # correct positive
        pass
    else: # incorrect
        err += 1
    if prediction > 0:
        pos += 1
        
score = err /1000 


time2 = time.time()

print("best dev err %.1f%%, |w|=%d, time: %.1f secs, with %.0f positives" % (score * 100, len(mapping), time2-time1, pos))
# Out:
# best dev err 25.6%, |w|=15805, time: 18.6 secs, with 500 positives

# %%
# TEST ON BLIND DATA AND OUTPUT DATA FILE
x_test, y_test, mapping = binarize(testpath, mapping)

y_predict = list(lr.predict(x_test))


with open('test.txt.predicted.txt', 'w') as file:
    for i,row in enumerate(y_predict):
        if i + 1 < len(y_predict):
            if row == 1:
                file.write('+' + '\n')
            else:
                file.write('-' + '\n')
        else:
            if row == 1:
                file.write('+' + '\n')
            else:
                file.write('-' + '\n')
file.close()

# %%
row
# Out:
# 1

# %% [markdown]
# # 5 Deployment

# %%
# Remove stop words
import nltk
nltk.download('punkt')
from nltk.corpus import *
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tanku\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tanku\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def train_drop_stop(trainfile, devfile, epochs=5):
    t = time.time()
    best_err = 1.
    model = svector()
    model_a = svector()
    c = 0
    for it in range(1, epochs+1):
        updates = 0
        for i, (label, words) in enumerate(read_from(trainfile), 1): # label is +1 or -1
            text_tokens = word_tokenize(" ".join(words))

            clean_words = [word for word in text_tokens if not word in stopwords.words()]            
            
            sent = make_vector(clean_words)
            
            c += 1
            if label * (model.dot(sent)) <= 0:
                updates += 1
                model += label * sent
                model_a += c * label * sent
        dev_err = test(devfile, c * model - model_a)
        #dev_err = test(devfile, model)
        best_err = min(best_err, dev_err)
        print("epoch %d, update %.1f%%, dev %.1f%%" % (it, updates / i * 100, dev_err * 100))
    print("best dev err %.1f%%, |w|=%d, time: %.1f secs" % (best_err * 100, len(model), time.time() - t))
    return model_a

print('test')
weight_avg = train_drop_stop(trainpath, devpath, 5)



#epoch 1, update 39.3%, dev 31.0%
#epoch 2, update 23.0%, dev 27.7%
#epoch 3, update 16.8%, dev 27.2%
#epoch 4, update 12.9%, dev 26.9%
#epoch 5, update 10.2%, dev 27.1%
# drop stop length 12,304
# Out:
# test
# epoch 1, update 39.3%, dev 31.0%
# epoch 2, update 23.0%, dev 27.7%
# epoch 3, update 16.8%, dev 27.2%
# epoch 4, update 12.9%, dev 26.9%
# epoch 5, update 10.2%, dev 27.1%
# best dev err 26.9%, |w|=15487, time: 91017.2 secs

# %%
weight_avg
# Out:
# svector(float,
#         {"'s": 241946.0,
#          'tour': 43467.0,
#          'force': -1869.0,
#          ',': 27157.0,
#          'written': -9042.0,
#          'directed': 56931.0,
#          'quietly': 15094.0,
#          'implosion': 1.0,
#          'rather': 218.0,
#          'explosion': -8781.0,
#          'fear': -3639.0,
#          'bias': -58063.0,
#          'places': 74622.0,
#          'slightly': 25584.0,
#          'believable': 53120.0,
#          'love': 2514.0,
#          'triangle': -15119.0,
#          'difficult': -2247.0,
#          'swallow': -30300.0,
#          'setting': 16289.0,
#          'disappointingly': -28615.0,
#          'moves': 20070.0,
#          'story': -81548.0,
#          'realm': -41421.0,
#          'improbable': 32881.0,
#          'thriller': -51192.0,
#          'indulgent': 14081.0,
#          'sunbaked': 24006.0,
#          'summery': 24006.0,
#          'mind': -22449.0,
#          'sex': 23991.0,
#          'lucia': 24006.0,
#          'may': -70792.0,
#          'well': 72800.0,
#          'prove': 37282.0,
#          'diverting': 108749.0,
#          'enough': -41891.0,
#          'exactly': -3729.0,
#          "'d": -94111.0,
#          'expect': -23691.0,
#          'guy': 31066.0,
#          'named': -12087.0,
#          'kaos': -4.0,
#          'eastwood': 22668.0,
#          'winces': -48024.0,
#          'clutches': -48024.0,
#          'chest': 27747.0,
#          'gasps': -48024.0,
#          'breath': 47920.0,
#          'spectacular': -31357.0,
#          'performance': -51477.0,
#          'ahem': -48024.0,
#          'hope': 31308.0,
#          'acting': -25078.0,
#          'stage': 13363.0,
#          'director': 82441.0,
#          'sam': -51108.0,
#          'mendes': -27647.0,
#          'showcases': -110195.0,
#          'tom': 72058.0,
#          'hanks': -16304.0,
#          'depression': 28342.0,
#          'hit': -141256.0,
#          'dark': 6223.0,
#          'revenge': 85866.0,
#          'minor': 54120.0,
#          'figures': -14812.0,
#          'surrounding': -49700.0,
#          'bobby': 10.0,
#          'form': 64712.0,
#          'gritty': 10136.0,
#          'urban': -74603.0,
#          'mosaic': 10.0,
#          'extremely': -61961.0,
#          'bad': 40459.0,
#          'every': 29303.0,
#          'sequel': -28616.0,
#          'skip': 32148.0,
#          'two': -33333.0,
#          'hours': -37418.0,
#          'gained': -62337.0,
#          'consider': -88586.0,
#          'review': 55215.0,
#          'life': -7163.0,
#          'affirming': -1217.0,
#          'three': 34597.0,
#          'films': 14487.0,
#          'remarkably': 18599.0,
#          'cohesive': 18153.0,
#          'whole': -23269.0,
#          'visually': 44020.0,
#          'thematically': -5776.0,
#          'consistently': -53342.0,
#          'sensitive': -16874.0,
#          'often': -37662.0,
#          'exciting': 39119.0,
#          'treatment': 32654.0,
#          'ignored': -6330.0,
#          'people': 55718.0,
#          'viewers': -25114.0,
#          'barney': -16.0,
#          'crushingly': -16.0,
#          'self': 23473.0,
#          'spectacle': -40953.0,
#          'see': -23950.0,
#          'nothing': 3034.0,
#          'match': 18469.0,
#          'ordeal': -16.0,
#          'sitting': -75840.0,
#          'admired': 62402.0,
#          'work': 14241.0,
#          'lot': -8513.0,
#          'sinister': 42144.0,
#          'inspiration': 30416.0,
#          'fuelled': -20.0,
#          'devito': -28518.0,
#          'early': -23845.0,
#          'confused': -27354.0,
#          'death': -90110.0,
#          'smoochy': -11883.0,
#          'something': -46687.0,
#          'ugly': -51741.0,
#          'mindless': -75387.0,
#          'somewhat': 16051.0,
#          'clumsy': -29645.0,
#          'lethargically': -6982.0,
#          'paced': -3407.0,
#          'mysterious': -6756.0,
#          'creature': 28801.0,
#          'psychic': 21.0,
#          'abilities': -7862.0,
#          'offers': 25150.0,
#          'solid': 5400.0,
#          'build': 31565.0,
#          'terrific': 17264.0,
#          'climax': -46336.0,
#          'nice': -17098.0,
#          'chills': -59059.0,
#          'along': 35660.0,
#          'way': 3181.0,
#          'better': 98616.0,
#          'phantom': -8344.0,
#          'menace': -24236.0,
#          'unless': -69553.0,
#          "'re": -53.0,
#          'absolute': 135.0,
#          'raving': -22.0,
#          'star': 135600.0,
#          'wars': 73596.0,
#          'junkie': 53710.0,
#          "n't": 34940.0,
#          'much': -7393.0,
#          'fun': 26031.0,
#          'herzog': -7130.0,
#          'least': -37033.0,
#          'inspired': -27272.0,
#          'works': -18864.0,
#          'unimaginative': -34957.0,
#          'nasty': -76825.0,
#          'glibly': -32048.0,
#          'cynical': 88506.0,
#          'piece': 52790.0,
#          'remarkable': 71178.0,
#          '(': -66544.0,
#          'frustrating': -19149.0,
#          ')': -99976.0,
#          'thing': -8158.0,
#          'world': 41495.0,
#          'traveler': 33766.0,
#          'opens': -76333.0,
#          'today': -97860.0,
#          'manhattan': 15278.0,
#          'protagonist': -76971.0,
#          'object': 3593.0,
#          'intense': 34533.0,
#          'scrutiny': -10074.0,
#          '104': -24050.0,
#          'minutes': -73203.0,
#          'remains': 49067.0,
#          'complete': 76423.0,
#          'blank': 3689.0,
#          'beautifully': 7475.0,
#          'produced': -32028.0,
#          'big': 2577.0,
#          'fat': -20712.0,
#          'greek': -30641.0,
#          'wedding': 86261.0,
#          'best': -31030.0,
#          'date': -4515.0,
#          'movie': -38410.0,
#          'year': 46166.0,
#          'dare': -45539.0,
#          'say': 36906.0,
#          'twice': -19535.0,
#          'delightfully': 21902.0,
#          'charming': 5975.0,
#          'totally': -11973.0,
#          'american': 5292.0,
#          'might': -80727.0,
#          'add': -29852.0,
#          'slice': -28150.0,
#          'comedic': -7491.0,
#          'bliss': -13133.0,
#          'refreshing': -29141.0,
#          'romance': 3767.0,
#          'smart': 14399.0,
#          'even': 126.0,
#          'pronounce': -35358.0,
#          'gyro': 31.0,
#          'correctly': -44115.0,
#          "'ll": -47973.0,
#          'appreciate': 3421.0,
#          'vardalos': 20621.0,
#          "'": -10512.0,
#          'humor': -39383.0,
#          'transcends': 19910.0,
#          'ethnic': 31.0,
#          'boundaries': 31.0,
#          'wonder': 40668.0,
#          'music': 42511.0,
#          'video': -13813.0,
#          'full': 51708.0,
#          'length': -81653.0,
#          'science': 23862.0,
#          'fiction': 32196.0,
#          'pastiche': -2858.0,
#          'lacking': -61219.0,
#          'originality': 73116.0,
#          'stripped': 39633.0,
#          'away': 783.0,
#          'inspirations': -34.0,
#          'would': -31846.0,
#          'precious': -48125.0,
#          'little': -74781.0,
#          'left': -35590.0,
#          'austin': -31492.0,
#          'powers': 12525.0,
#          'part': 32329.0,
#          'funny': 1426.0,
#          'first': 10110.0,
#          'making': 33817.0,
#          'flaws': 93430.0,
#          'later': 13154.0,
#          'turns': -67246.0,
#          'numbingly': -36.0,
#          'dull': 9336.0,
#          'witted': 10356.0,
#          'disquietingly': -36.0,
#          'creepy': -38327.0,
#          '`': 1893.0,
#          'sophisticated': 106115.0,
#          'refuse': -24111.0,
#          'admit': 37283.0,
#          'like': 17611.0,
#          'likely': 17215.0,
#          'call': 17043.0,
#          'challenging': 67694.0,
#          'fellow': 37852.0,
#          'sophisticates': -24111.0,
#          'lika': 38.0,
#          'accents': 38.0,
#          'good': 15913.0,
#          'thoroughly': 89099.0,
#          'enjoyed': 29739.0,
#          'scott': -3925.0,
#          'baio': 38.0,
#          'turning': 13553.0,
#          'delightful': 53560.0,
#          'indie': 36588.0,
#          'projects': 36581.0,
#          'bland': -99645.0,
#          'pretentious': -91762.0,
#          'mess': 33774.0,
#          'final': 34096.0,
#          'result': -19058.0,
#          'makes': -32759.0,
#          'adequate': -12457.0,
#          'entertainment': -27985.0,
#          'suppose': -41.0,
#          'anyone': -14879.0,
#          'seen': -10411.0,
#          'chicago': 19537.0,
#          'leave': 30754.0,
#          'theater': -24862.0,
#          'feeling': 23411.0,
#          "'ve": 22614.0,
#          'watched': 44183.0,
#          'pale': -47522.0,
#          'imitation': -30940.0,
#          'real': 31631.0,
#          'deal': -82838.0,
#          'undisputed': 23292.0,
#          'worst': -59156.0,
#          'boxing': -41544.0,
#          'ever': -16982.0,
#          'certainly': -57064.0,
#          'champion': -42.0,
#          'loser': 29500.0,
#          'audience': -10953.0,
#          'fanciful': -5006.0,
#          'drama': -12949.0,
#          'napoleon': 27603.0,
#          'last': -14335.0,
#          'years': 81027.0,
#          'surprising': 6507.0,
#          'discovery': 21406.0,
#          'humility': 49.0,
#          'pretty': -45878.0,
#          'linear': 50.0,
#          'makeup': -77253.0,
#          'deep': -47612.0,
#          'bogdanovich': 4201.0,
#          'ties': 1606.0,
#          'together': -44515.0,
#          'efficiency': 50.0,
#          'affection': 80588.0,
#          'period': -22038.0,
#          'antonia': 33505.0,
#          'assimilated': 32153.0,
#          'newfangled': 32153.0,
#          'community': 28276.0,
#          'film': -63991.0,
#          'settles': -25591.0,
#          'becomes': -2794.0,
#          'compulsively': 17389.0,
#          'watchable': 100228.0,
#          'guilty': -46567.0,
#          'pleasure': 160734.0,
#          'daytime': -21175.0,
#          'sort': -24050.0,
#          'fashion': -27148.0,
#          'slow': 40960.0,
#          'moving': -25741.0,
#          'swedish': -30845.0,
#          'hint': -60595.0,
#          'joy': 19326.0,
#          'preferring': -48165.0,
#          'focus': -20598.0,
#          'humiliation': -48165.0,
#          'martin': 12149.0,
#          'defecates': -48165.0,
#          'bed': -48165.0,
#          'urinates': -48165.0,
#          'plants': -48165.0,
#          'birthday': -36494.0,
#          'party': 7719.0,
#          'able': 32317.0,
#          'provide': -26323.0,
#          'insight': 23717.0,
#          'fascinating': 51882.0,
#          'history': 33232.0,
#          'series': 42764.0,
#          'died': -31115.0,
#          'long': -60535.0,
#          'ago': -36465.0,
#          'keep': -31375.0,
#          'bringing': 60978.0,
#          'back': 32638.0,
#          'another': 103653.0,
#          'day': 31643.0,
#          'punishment': 32086.0,
#          'paying': 5609.0,
#          'money': -46077.0,
#          'james': -25284.0,
#          'bond': 86454.0,
#          'sheridan': -103510.0,
#          'wonderful': 47494.0,
#          'account': -5813.0,
#          'curiously': 34950.0,
#          'waters': -77522.0,
#          'grit': -56240.0,
#          'vulnerability': -82081.0,
#          'light': -7643.0,
#          'reading': -9537.0,
#          'happiest': 62.0,
#          'surprise': -53157.0,
#          'deals': 11498.0,
#          'subject': -16283.0,
#          'always': 66091.0,
#          'proves': 13070.0,
#          'quite': 94676.0,
#          'compelling': -53262.0,
#          'brooding': 8140.0,
#          'character': 576.0,
#          'study': 29086.0,
#          'thanks': 99435.0,
#          'ch': -19244.0,
#          'teau': -19244.0,
#          'balance': 12947.0,
#          'whimsicality': 16150.0,
#          'narrative': 62334.0,
#          'discipline': 16150.0,
#          'serious': 37035.0,
#          'improvisation': 16150.0,
#          'almost': 19219.0,
#          'relationship': -5301.0,
#          'personality': -1535.0,
#          'yields': -4782.0,
#          'surprises': -44385.0,
#          'leaks': -42426.0,
#          'treacle': -76.0,
#          'pore': -76.0,
#          'gently': 38110.0,
#          'humorous': -30016.0,
#          'touching': 70884.0,
#          'disposable': -1505.0,
#          'tissue': -82.0,
#          'wild': -5928.0,
#          'card': -317.0,
#          'john': -17166.0,
#          'turturro': 2124.0,
#          'simply': 18961.0,
#          'fab': -82.0,
#          'spanish': -533.0,
#          'butler': 2124.0,
#          'foot': -94056.0,
#          'fetish': -82.0,
#          'stunning': -22117.0,
#          'visuals': 40388.0,
#          'staggeringly': -37066.0,
#          'boring': 14498.0,
#          'cinema': 35382.0,
#          'judith': 85.0,
#          'zaza': 85.0,
#          'extended': 61892.0,
#          'bedroom': -11700.0,
#          'sequence': -26866.0,
#          'intimate': 29252.0,
#          'sensual': -2569.0,
#          'psychologically': 4583.0,
#          'revealing': 17428.0,
#          'passes': -57179.0,
#          'movies': -11057.0,
#          'look': -62685.0,
#          'cheap': -51585.0,
#          'hysterics': 85.0,
#          'lanie': -32258.0,
#          'professional': -17875.0,
#          'success': 5113.0,
#          'means': -28358.0,
#          'must': 39379.0,
#          'failure': -8744.0,
#          'driven': -22133.0,
#          'ambition': -22848.0,
#          'know': 13609.0,
#          'mr': 17047.0,
#          'caine': -42780.0,
#          'fraser': -49580.0,
#          'show': -78879.0,
#          'memorable': 29802.0,
#          'resourceful': 87.0,
#          'performances': 37529.0,
#          'however': -41634.0,
#          'sincere': 10029.0,
#          'rising': -13212.0,
#          'place': -26362.0,
#          'never': -41905.0,
#          'justifies': -89.0,
#          'existence': 2446.0,
#          'aaa': 8184.0,
#          'action': -6951.0,
#          'xxx': 22107.0,
#          'blast': 32335.0,
#          'adrenalin': 8184.0,
#          'rated': -51124.0,
#          'eee': 8184.0,
#          'excitement': -36361.0,
#          'vin': 15518.0,
#          'diesel': -52338.0,
#          'obstacles': 18915.0,
#          'easily': -40585.0,
#          'overcome': -1092.0,
#          'development': -22995.0,
#          'script': -32565.0,
#          'tells': -5942.0,
#          'brian': 37371.0,
#          'palma': 55083.0,
#          'addiction': -96.0,
#          'junk': -43557.0,
#          'calorie': -96.0,
#          'suspense': 88966.0,
#          'tropes': -40397.0,
#          'ruined': -96.0,
#          'career': 35086.0,
#          'special': 49827.0,
#          'effects': 42706.0,
#          'many': 69367.0,
#          'scenes': 46046.0,
#          'weightlessness': 97.0,
#          'original': 54263.0,
#          'oscar': -5715.0,
#          'winning': 17734.0,
#          'sound': 1926.0,
#          'horner': 97.0,
#          'rousing': 73965.0,
#          'score': 39365.0,
#          'make': 57344.0,
#          'use': 62606.0,
#          'hefty': 28331.0,
#          'audio': 97.0,
#          'system': 9130.0,
#          'steven': 16427.0,
#          'soderbergh': 12702.0,
#          'solaris': 33748.0,
#          'glorious': 95129.0,
#          'streets': 34957.0,
#          'shot': -10172.0,
#          'cinematographer': 20994.0,
#          'michael': -326.0,
#          'ballhaus': -100.0,
#          'authentic': 105263.0,
#          'mean': 24616.0,
#          'nearly': -41115.0,
#          'impossible': 65118.0,
#          'happens': -725.0,
#          'stirring': 21050.0,
#          'finally': -124659.0,
#          'transporting': 103.0,
#          'imagining': 103.0,
#          'beauty': -17904.0,
#          'beast': -25206.0,
#          '1930s': 103.0,
#          'horror': -50853.0,
#          'stark': 14384.0,
#          'reminder': 50553.0,
#          'casualties': 8210.0,
#          'reach': -45368.0,
#          'imagine': -27697.0,
#          'jir': 107.0,
#          'hubac': 107.0,
#          'gem': 79207.0,
#          'characters': 69150.0,
#          'engaging': 48942.0,
#          'dialogue': -31063.0,
#          'realistic': 56572.0,
#          'greatly': 25160.0,
#          'scope': 72346.0,
#          'silberstein': 107.0,
#          'family': -12672.0,
#          'large': 29756.0,
#          'grow': 39702.0,
#          'attached': 2349.0,
#          'lives': 76263.0,
#          'strength': 85526.0,
#          'warmth': 85377.0,
#          'vitality': 25324.0,
#          'elegantly': -43651.0,
#          'crafted': -20205.0,
#          'anderson': 15977.0,
#          'essentially': -20859.0,
#          'trick': 18899.0,
#          'pony': -109.0,
#          'hampered': -42069.0,
#          'undeveloped': -109.0,
#          'ultimately': 37122.0,
#          'pulls': 65589.0,
#          'lame': -48408.0,
#          'mike': 57700.0,
#          'interested': -52246.0,
#          'recycling': 27034.0,
#          'old': 38846.0,
#          'cliches': -4544.0,
#          'wants': -55246.0,
#          'tweak': 48440.0,
#          'taste': 20377.0,
#          'tangy': 48440.0,
#          'new': 9493.0,
#          'stormy': -112.0,
#          'night': -13152.0,
#          'key': 26538.0,
#          'moments': 55185.0,
#          'splash': 42289.0,
#          'clever': 35983.0,
#          'unflinching': 9806.0,
#          'comic': 3783.0,
#          'barbs': 114.0,
#          'slap': -46729.0,
#          'small': 53368.0,
#          'rewarding': 25413.0,
#          'comedy': 59197.0,
#          'takes': -66718.0,
#          'aim': 4425.0,
#          'contemporary': 24447.0,
#          'southern': -24926.0,
#          'adolescence': 33432.0,
#          'lets': 6235.0,
#          'whether': -1465.0,
#          '10': -33089.0,
#          'inch': 16230.0,
#          'television': 41294.0,
#          'screen': -72656.0,
#          'local': -57180.0,
#          'multiplex': 16452.0,
#          'edge': 38166.0,
#          'seat': -1234.0,
#          'educational': 50150.0,
#          'antics': 5759.0,
#          'steve': 76505.0,
#          'irwin': -95013.0,
#          'priceless': 16230.0,
#          'using': 20943.0,
#          'stock': 30599.0,
#          'plot': 81214.0,
#          'boy': -7633.0,
#          'injects': 43362.0,
#          'freshness': 40301.0,
#          'proceedings': 34573.0,
#          'enjoyable': 18917.0,
#          '100': -14020.0,
#          'really': -60444.0,
#          'premise': 606.0,
#          'frittered': -119.0,
#          'middle': -23326.0,
#          'road': 37227.0,
#          'blandness': -29515.0,
#          'scooby': -9698.0,
#          'doo': -14758.0,
#          'retro': -22665.0,
#          'refitting': -123.0,
#          'exercise': -41710.0,
#          'campy': -19859.0,
#          'recall': -2321.0,
#          'older': 59045.0,
#          'fans': -47764.0,
#          'silly': -5424.0,
#          'nickelodeon': 50752.0,
#          'esque': 33951.0,
#          'kiddie': 27995.0,
#          'flick': -26402.0,
#          'unfunny': -17473.0,
#          'clocks': -126.0,
#          '80': 57288.0,
#          'feels': -22195.0,
#          'looks': 17330.0,
#          'closely': -664.0,
#          'insightfully': 127.0,
#          'fragile': -833.0,
#          'complex': -18228.0,
#          'relationships': 30055.0,
#          'book': 2376.0,
#          'page': 44620.0,
#          'turner': 56516.0,
#          'wait': -3564.0,
#          'next': -17214.0,
#          'scene': -71740.0,
#          'wreaks': -131.0,
#          'routine': -79052.0,
#          'manages': 46906.0,
#          'generate': -46953.0,
#          'single': -4421.0,
#          'threat': -49647.0,
#          'barely': 26392.0,
#          'goes': -43903.0,
#          'beyond': 13761.0,
#          'status': 3243.0,
#          'discursive': 135.0,
#          'oddly': -10380.0,
#          'riveting': 56460.0,
#          'documentary': 20774.0,
#          'worth': 73647.0,
#          'bucks': -73320.0,
#          'expend': -80685.0,
#          'price': 93001.0,
#          'comes': 47018.0,
#          'rental': -83123.0,
#          'achingly': 26928.0,
#          'enthralling': 29263.0,
#          'hindered': 13778.0,
#          'uneven': 33317.0,
#          'lapses': 26341.0,
#          'thurman': 142.0,
#          'lewis': 3631.0,
#          'hilarious': 46814.0,
#          'throughout': -28282.0,
#          'amari': -29733.0,
#          'dressed': -27897.0,
#          'parable': -28623.0,
#          'fairly': -69173.0,
#          'irresistible': 91797.0,
#          'package': 3465.0,
#          'privileged': 27453.0,
#          'utterly': -36909.0,
#          'predictable': 145273.0,
#          'completely': 38057.0,
#          'void': -20562.0,
#          'anything': -67308.0,
#          'remotely': -3598.0,
#          'interesting': -63546.0,
#          'suspenseful': 87709.0,
#          'maker': 23268.0,
#          'spielberg': 96463.0,
#          'decades': 9918.0,
#          'since': 108233.0,
#          'schlepping': 146.0,
#          'indiana': 146.0,
#          'jones': 32011.0,
#          'around': 21597.0,
#          'globe': 13204.0,
#          'search': -14685.0,
#          'giant': -118336.0,
#          'misplaced': -81227.0,
#          'ashtray': 146.0,
#          'sweet': 23569.0,
#          'bit': 6422.0,
#          'start': -40213.0,
#          'familiar': -81303.0,
#          'yes': 61786.0,
#          'enjoys': -8298.0,
#          'seeing': -55668.0,
#          'joan': -16508.0,
#          'awkward': 39416.0,
#          'young': 28226.0,
#          'woman': 44413.0,
#          'strong': 78535.0,
#          'determined': 40811.0,
#          'monarch': -8298.0,
#          'philandering': -8298.0,
#          'philip': -42086.0,
#          'diminishes': -8298.0,
#          'stature': -49598.0,
#          'justine': 48600.0,
#          'wondering': 4389.0,
#          'happen': 19374.0,
#          'wishing': -17156.0,
#          'whatever': -10769.0,
#          'times': 17655.0,
#          'guys': -40688.0,
#          'taps': 152.0,
#          'powerful': 2210.0,
#          'emotions': 63256.0,
#          'kind': 37290.0,
#          'material': -52116.0,
#          'effective': 2452.0,
#          'motion': 154301.0,
#          'picture': 61307.0,
#          'static': 22381.0,
#          'missed': -44345.0,
#          'boat': -1265.0,
#          'cinematic': -1193.0,
#          'pyrotechnics': -4374.0,
#          'aside': 8625.0,
#          'avary': -14612.0,
#          'seems': -14957.0,
#          'giggles': -31273.0,
#          'pulchritude': -154.0,
#          'sense': 11379.0,
#          'went': 40970.0,
#          'school': -12710.0,
#          'check': 107055.0,
#          'girls': -10182.0,
#          'frat': -4774.0,
#          'idea': -108666.0,
#          'time': -21102.0,
#          'centering': 157.0,
#          'traditional': 11434.0,
#          'indian': 39421.0,
#          'delhi': 157.0,
#          'specialized': 157.0,
#          'fare': 22729.0,
#          'mira': -31781.0,
#          'nair': -5722.0,
#          'delight': 23737.0,
#          'audiences': 64303.0,
#          'problem': -75664.0,
#          'joel': 23446.0,
#          'schumacher': -159.0,
#          'jams': -159.0,
#          'prefabricated': -159.0,
#          'elements': -62848.0,
#          'running': -19025.0,
#          'proclaim': 161.0,
#          'truth': -23986.0,
#          'struck': 1416.0,
#          'somebodies': 161.0,
#          'permits': 52186.0,
#          'space': 16627.0,
#          'convince': -23092.0,
#          'us': 192716.0,
#          'heady': 26088.0,
#          'children': 72927.0,
#          'preachy': 22969.0,
#          'adults': -45169.0,
#          'morvern': -47032.0,
#          'rocks': 2044.0,
#          'friend': -12125.0,
#          'beginning': 28055.0,
#          'omission': -8338.0,
#          'screenplay': -15690.0,
#          'rigid': -56212.0,
#          'evasive': -24513.0,
#          'ways': 29105.0,
#          'erin': -24513.0,
#          'brockovich': -24513.0,
#          'sight': 9593.0,
#          'ocean': 9219.0,
#          'eleven': -24513.0,
#          'wise': -36106.0,
#          'race': 19113.0,
#          'culture': 28391.0,
#          'forcefully': 6844.0,
#          'told': 26122.0,
#          'superb': 9065.0,
#          'alone': -21863.0,
#          'metropolis': 97837.0,
#          'hits': -2916.0,
#          'park': -255.0,
#          "'em": 745.0,
#          'anymore': 179.0,
#          'department': 68803.0,
#          'abuse': -53595.0,
#          'infidelity': 24540.0,
#          'usually': 27055.0,
#          'turpin': 24540.0,
#          'allows': 64674.0,
#          'chuckle': 21511.0,
#          'angst': 20652.0,
#          'filmmaker': 16373.0,
#          'writer': 12482.0,
#          'dylan': -3375.0,
#          'kidd': -183.0,
#          'ear': 15368.0,
#          'ring': -52223.0,
#          'remember': 69626.0,
#          'haunting': 34905.0,
#          'images': 79866.0,
#          'holes': -43682.0,
#          'falls': 36561.0,
#          'short': 16426.0,
#          'explaining': -190.0,
#          'roots': -6538.0,
#          'uncomfortable': 6475.0,
#          'experience': 33193.0,
#          'brave': 26604.0,
#          'could': 83220.0,
#          'possibly': -668.0,
#          'days': -36381.0,
#          'taut': 53276.0,
#          'psychological': -5147.0,
#          'waste': -46868.0,
#          'moment': -16337.0,
#          'hour': -12475.0,
#          'ricci': -11582.0,
#          'yet': -39360.0,
#          'girl': 6412.0,
#          'sincerely': 20946.0,
#          'believes': 24600.0,
#          'thwart': 16386.0,
#          'misery': -71443.0,
#          'blind': -48232.0,
#          'delivers': -22453.0,
#          'sexy': 25139.0,
#          'razzle': 194.0,
#          'dazzle': 194.0,
#          'everyone': -3081.0,
#          'especially': 16136.0,
#          'musical': -3503.0,
#          'hoping': 35898.0,
#          'cockeyed': -56585.0,
#          'ought': -58264.0,
#          'directing': -56735.0,
#          'license': -50310.0,
#          'burns': -26531.0,
#          'revoked': -197.0,
#          'romanek': 65273.0,
#          'keeps': 29937.0,
#          'adding': 55683.0,
#          'flourishes': -20845.0,
#          'artsy': -14335.0,
#          'fantasy': 58587.0,
#          'sequences': -33471.0,
#          'feel': -48267.0,
#          'wrong': -58632.0,
#          'cheapen': -8402.0,
#          'overall': 18548.0,
#          'effect': 60085.0,
#          'solondz': -25489.0,
#          'tries': -132070.0,
#          'hard': -41015.0,
#          'storytelling': -21606.0,
#          'fails': -70727.0,
#          'inside': 69091.0,
#          'column': 2860.0,
#          'torn': 4535.0,
#          'jacket': -203.0,
#          'ultimate': 785.0,
#          'scorsese': -30611.0,
#          'stomach': -9834.0,
#          'violence': -128920.0,
#          'colorful': 66931.0,
#          'york': -7483.0,
#          'gang': 4423.0,
#          'lore': 24408.0,
#          'hallmarks': 16743.0,
#          'personal': 53255.0,
#          'painted': -8798.0,
#          'largest': 24408.0,
#          'historical': 22890.0,
#          'canvas': 24408.0,
#          'witness': -2494.0,
#          'conflict': -75423.0,
#          'palestinian': -205.0,
#          'side': -68017.0,
#          'longley': -205.0,
#          'lacks': -32652.0,
#          'put': 6751.0,
#          'struggle': -18503.0,
#          'meaningful': 64585.0,
#          'context': -13964.0,
#          'ritchie': -25707.0,
#          'reduces': -50583.0,
#          'wertmuller': -1724.0,
#          'social': -23780.0,
#          'mores': 3578.0,
#          'politics': 1238.0,
#          'tiresome': -30700.0,
#          'jargon': -206.0,
#          'disturbingly': 2317.0,
#          'superficial': -47334.0,
#          'approach': -48725.0,
#          'mildly': -88000.0,
#          'pleasant': -9575.0,
#          'outing': 5165.0,
#          'r': -75220.0,
#          'rating': 18137.0,
#          'brief': 24267.0,
#          'nudity': 32416.0,
#          'grisly': 32416.0,
#          'corpse': -16642.0,
#          'aloft': 32416.0,
#          'referential': 32416.0,
#          'hot': 51445.0,
#          'air': 49236.0,
#          'tim': 94379.0,
#          'plays': 3045.0,
#          'guns': -35225.0,
#          'jokes': -20556.0,
#          'understands': -32191.0,
#          'generation': 25505.0,
#          'defines': -1431.0,
#          'jerking': -19819.0,
#          'byzantine': 2744.0,
#          'incarnations': -16424.0,
#          'bother': -93531.0,
#          'pleasuring': -16424.0,
#          'conditioning': 33064.0,
#          'griffin': 2355.0,
#          'co': -7125.0,
#          'manage': -24770.0,
#          'spectacularly': -8473.0,
#          'outrageous': -16248.0,
#          'whodunit': -19761.0,
#          'level': -92471.0,
#          'larger': -14281.0,
#          'themes': -46131.0,
#          'get': 103382.0,
#          'lost': -16070.0,
#          'murk': -32648.0,
#          'pure': 32543.0,
#          'participatory': 217.0,
#          'event': 38077.0,
#          'malnourished': 217.0,
#          'intellectuals': 217.0,
#          'gulp': 217.0,
#          'frenzy': -4678.0,
#          'chemistry': 22172.0,
#          'women': 88331.0,
#          'droll': 13314.0,
#          'stealing': -17331.0,
#          'wit': 17703.0,
#          'wolfish': 218.0,
#          'pessimism': 218.0,
#          'anna': 30539.0,
#          'chancellor': 218.0,
#          'weddings': 58155.0,
#          'funeral': 57252.0,
#          'lawrence': 39627.0,
#          'stick': 27700.0,
#          'job': 76776.0,
#          'actor': -64067.0,
#          'standup': -219.0,
#          'comedian': 16695.0,
#          'greatness': 20684.0,
#          'disingenuous': -48633.0,
#          'reno': 52736.0,
#          'great': -51626.0,
#          'flicks': 45871.0,
#          'distraction': -31670.0,
#          'friday': -32679.0,
#          'diversion': 6240.0,
#          'excuse': -83411.0,
#          'eat': 8908.0,
#          'popcorn': 87897.0,
#          'nettelbeck': -10543.0,
#          'pleasing': 68578.0,
#          'metaphor': 64990.0,
#          'concept': 22231.0,
#          'came': -27593.0,
#          'handed': -12486.0,
#          'gods': -228.0,
#          'silver': 6175.0,
#          ...})
